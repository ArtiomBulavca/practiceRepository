# %%
import seaborn as sns

# %%
lab2_data = sns.load_dataset('titanic')
lab2_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
custom_palette = {'First': 'blue', 'Second': 'orange', 'Third': 'green'}
plt.figure(figsize=(10, 6))
sns.barplot(data=lab2_data, x='class', y='survived', palette=custom_palette)
plt.ylabel('Survived')
plt.xlabel('Class')
plt.show()
# Out:
# <ipython-input-24-d5c8cbb2a71e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=lab2_data, x='class', y='survived', palette=custom_palette)

# %%
import seaborn as sns

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who')
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
import pandas as pd
lab2_data.loc[(lab2_data['who'] == 'child') & (lab2_data['sex'] == 'male'), 'who'] = 'boy'
lab2_data.loc[(lab2_data['who'] == 'child') & (lab2_data['sex'] == 'female'), 'who'] = 'girl'

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who')
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90)
# Out:
# <ipython-input-29-6fc1f79693e4>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90)
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who', ci=90, capsize=0.05)
# Out:
# <ipython-input-30-1857ca224616>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data, x='class', y='survived', hue='who', ci=90, capsize=0.05)
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(data=lab2_data, x='survived', y='age', hue='who',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
lab2_data.loc[(lab2_data['survived'] == 0), 'survived_str'] = 'no'
lab2_data.loc[(lab2_data['survived'] == 1),  'survived_str'] = 'yes'

# %%
lab2_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone survived_str
# 0      man        True  NaN  Southampton    no  False           no
# 1    woman       False    C    Cherbourg   yes  False          yes
# 2    woman       False  NaN  Southampton   yes   True          yes
# 3    woman       False    C  Southampton   yes  False          yes
# 4      man        True  NaN  Southampton    no   True           no
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True           no
# 887  woman       False    B  Southampton   yes   True          yes
# 888  woman       False  NaN  Southampton    no  False           no
# 889    man        True    C    Cherbourg   yes   True          yes
# 890    man        True  NaN   Queenstown    no   True           no
#
# [891 rows x 16 columns]

# %%
sns.barplot(data=lab2_data, x='survived', y='age', hue='who',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
import numpy as np

# %%
sns.barplot(data=lab2_data, x='survived', y='age', hue='who', estimator = np.median , ci=90, capsize=0.05,hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <ipython-input-36-e91fc1c37ce8>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data, x='survived', y='age', hue='who', estimator = np.median , ci=90, capsize=0.05,hue_order=['man', 'woman', 'boy', 'girl'])
# <Axes: xlabel='survived', ylabel='age'>

# %%
import numpy as np
sns.barplot(data=lab2_data, x='survived', y='age', hue='who',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(data=lab2_data, x='survived', y='age', hue='who',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.stripplot(data=lab2_data, x='survived', y='age', hue='who', jitter=0.3, alpha=0.5, dodge='true',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'
lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1,  'survived_str'] = 'yes'

# %%
sns.set_style("white")
sns.set_context("paper")

# %%
color_order={'man':'blue','woman':'tab:orange','boy':'cornflowerblue','girl':'sandybrown'}

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette=color_order)
# Out:
# <ipython-input-43-dd90a0e27d73>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette=color_order)
# <Axes: xlabel='class', ylabel='survived'>

# %%
custom_order = ['First', 'Third']

sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette=color_order, order=custom_order)
# Out:
# <ipython-input-44-4a7ba677dcec>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette=color_order, order=custom_order)
# <Axes: xlabel='class', ylabel='survived'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
custom_order = ['First', 'Third']

ax = sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette=color_order, order=custom_order)

ax.set_xlabel('Boarding Class')
ax.set_ylabel('Mean survival rate')

plt.show()
# Out:
# <ipython-input-45-eafece43c37a>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   ax = sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette=color_order, order=custom_order)

# %%
import numpy as np

# %%
sns.barplot(data=lab2_data, x='survived', y='age', hue='who',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(data=lab2_data, x='survived', y='age', hue='who',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.stripplot(data=lab2_data, x='survived', y='age', hue='who', jitter=0.3, alpha=0.5, dodge='true',hue_order=['man', 'woman', 'boy', 'girl'])
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'
lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1,  'survived_str'] = 'yes'

# %%
sns.set_style("white")
sns.set_context("paper")

# %%
{'man':'blue','woman':'tab:orange','boy':'cornflowerblue','girl':'sandybrown'}
# Out:
# {'man': 'blue',
#  'woman': 'tab:orange',
#  'boy': 'cornflowerblue',
#  'girl': 'sandybrown'}

# %%
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

# %%
sns.set_style("white")
sns.set_context("paper")

# %%
color_palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

# %%
sns.barplot(data=lab3_data, x='survived_str', y='age', hue='who', estimator=np.median, ci=90, capsize=0.05, palette=color_palette)
plt.title('Median Age of Survivors and Non-Survivors by Category')
plt.show()
# Out:
# <ipython-input-61-f6b3db992d94>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab3_data, x='survived_str', y='age', hue='who', estimator=np.median, ci=90, capsize=0.05, palette=color_palette)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

lab3_data = lab3_data[lab3_data['class'] != 'Second']

sns.set_style("white")
sns.set_context("paper")

color_palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

sns.barplot(data=lab3_data, x='class', y='age', hue='who', estimator=np.median, ci=90, capsize=0.05, palette=color_palette, order=['Third', 'First'])
plt.title('Median Age of Survivors and Non-Survivors by Category')
plt.show()
# Out:
# <ipython-input-63-40a4ca90f858>:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab3_data, x='class', y='age', hue='who', estimator=np.median, ci=90, capsize=0.05, palette=color_palette, order=['Third', 'First'])

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

lab3_data = lab3_data[lab3_data['class'] != 'Second']

sns.set_style("white")
sns.set_context("paper")

color_palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

ax = sns.barplot(data=lab3_data, x='class', y='survived', hue='who', estimator=np.mean, ci=90, capsize=0.05, palette=color_palette, order=['Third', 'First'])

ax.set(xlabel='Boarding Class', ylabel='Mean Survival Rate')

plt.title('Mean Survival Rate by Boarding Class and Category')
plt.show()
# Out:
# <ipython-input-65-5321eae049e0>:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   ax = sns.barplot(data=lab3_data, x='class', y='survived', hue='who', estimator=np.mean, ci=90, capsize=0.05, palette=color_palette, order=['Third', 'First'])

# %%
sns.despine()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

lab3_data = lab3_data[lab3_data['class'] != 'Second']

sns.set_style("white")
sns.set_context("paper")

ax = sns.boxplot(data=lab3_data, x='class', y='age', order=['Third', 'First'], color='white', fliersize=0)

ax.set(xlabel='Boarding Class', ylabel='Age')

plt.title('Age Distribution by Boarding Class')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

sns.set_style("whitegrid")
sns.set_context("paper")

color_palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

plt.figure(figsize=(10, 6))
ax = sns.stripplot(data=lab3_data, x='survived_str', y='age', hue='who', dodge=True, palette=color_palette)

ax.set(xlabel='survived_str', ylabel='age')

plt.title('Age Distribution by Survival Status and Category')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
fig, axes2 = plt.subplots(figsize=(10, 6))
sns.stripplot(data=lab3_data, x='survived_str', y='age', hue='who', jitter=0.3, alpha=0.7, dodge=True, ax=axes2)
sns.boxplot(data=lab3_data, x='survived_str', y='age', hue='who', ax=axes2, dodge=True, boxprops=dict(facecolor='white', alpha=1.0))  # Set boxprops to make boxplot fully visible and white

plt.xlabel('survived')
handles, labels = axes2.get_legend_handles_labels()
plt.legend(handles[4:8], labels[4:8], title='Who')

axes2.set_ylim(0, 80)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=lab3_data, x='survived_str', y='age', hue='who', palette='Set2')

plt.xlabel('Survived')
plt.ylabel('Age')

sns.despine()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic_data = sns.load_dataset('titanic')

sns.set_style("whitegrid")
sns.set_context("paper")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=titanic_data, x='age', y='fare', hue='class', palette='muted', s=100)

plt.xlabel('Age')
plt.ylabel('Fare')

sns.despine()
plt.title('Age vs. Fare Colored by Passenger Class')

plt.show()

# %%
lab3_data_subset=lab3_data[['class','who','fare']]
lab3_data_subset=lab3_data_subset.dropna(how='any')
lab3_data_subsetAverage=lab3_data_subset.groupby(['class','who']).mean()
lab3_data_subsetAverage=lab3_data_subsetAverage.reset_index()
lab3_data_subsetAverage.head()
# Out:
#     class    who        fare
# 0   First    boy  117.802767
# 1   First   girl  160.962500
# 2   First    man   65.951086
# 3   First  woman  104.317995
# 4  Second    boy   27.306022

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.set_context("paper")

matrix_data = lab3_data_subsetAverage.pivot(index='who', columns='class', values='fare')

plt.figure(figsize=(8, 6))
axes5 = sns.heatmap(data=matrix_data, annot=True, fmt='.2f', cmap='coolwarm')

for text in axes5.texts:
    text.set_text('£' + text.get_text())

axes5.set(xlabel='Boarding Class', ylabel='Demographic', xticklabels=['First', 'Second', 'Third'])

plt.title('Average Fare by Demographic and Boarding Class')

plt.show()
